# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
for f in ["toy", "test01", "test02", "test03", "test04", "test05", "test06"]:
    df = pd.read_csv(f"./logs/{f}.csv")
    plt.figure()
    plt.plot(range(len(df)), df["penalties"], label=f)
    plt.savefig(f"./logs/{f}.pdf")
