# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
for f, p in zip(["toy", "test01", "test02", "test03", "test04", "test05", "test06"], [269, 3976, 2443, 11624, 6524,18318, 34325]):
    df = pd.read_csv(f"./logs/{f}.csv")
    plt.figure()
    plt.plot(range(len(df)), df["penalties"], label=f)
    plt.axhline(y=p, color='r', linestyle='--')
